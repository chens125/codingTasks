# %% [markdown]
# ### Machine Learning Algorithms

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Linear regression (SLR,MLR)
# MLR
# * assumes little or no multicollinearity
# * Homogeneity of variance (homoscedasticity), size of residuals does not change significantly across values of independent variables
# * Regression residuals must be nornally distributed.
